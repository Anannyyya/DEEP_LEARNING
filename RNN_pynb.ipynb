# %% [markdown]
# <a href="https://colab.research.google.com/github/Anannyyya/python_examples/blob/master/RNN_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example Program on RNN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings("ignore")
warnings.warn("Do not show again!")
plt.rcParams["figure.figsize"]=(10,6)
sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%3f' % x)
import io
import plotly.express as px

# %%
#define dataset
train=pd.read_csv("/content/sample_data/rnn_train/DailyDelhiClimateTrain.csv")
test=pd.read_csv("/content/sample_data/rnn_test/DailyDelhiClimateTest.csv")

# %%
train.head()
# Out:
#          date  meantemp  humidity  wind_speed  meanpressure
# 0  2013-01-01 10.000000 84.500000    0.000000   1015.666667
# 1  2013-01-02  7.400000 92.000000    2.980000   1017.800000
# 2  2013-01-03  7.166667 87.000000    4.633333   1018.666667
# 3  2013-01-04  8.666667 71.333333    1.233333   1017.166667
# 4  2013-01-05  6.000000 86.833333    3.700000   1016.500000

# %%
test.head()
# Out:
#          date  meantemp  humidity  wind_speed  meanpressure
# 0  2017-01-01 15.913043 85.869565    2.743478     59.000000
# 1  2017-01-02 18.500000 77.222222    2.894444   1018.277778
# 2  2017-01-03 17.111111 81.888889    4.016667   1018.333333
# 3  2017-01-04 18.700000 70.050000    4.545000   1015.700000
# 4  2017-01-05 18.388889 74.944444    3.300000   1014.333333
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['meantemp'].plot(kind='hist', bins=20, title='meantemp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['humidity'].plot(kind='hist', bins=20, title='humidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['wind_speed'].plot(kind='hist', bins=20, title='wind_speed')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['meanpressure'].plot(kind='hist', bins=20, title='meanpressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_24.groupby('date').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_25.plot(kind='scatter', x='meantemp', y='humidity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26.plot(kind='scatter', x='humidity', y='wind_speed', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27.plot(kind='scatter', x='wind_speed', y='meanpressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['meantemp']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_28.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('meantemp')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['humidity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_29.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('humidity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['wind_speed']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_30.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('wind_speed')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['date']
#   ys = series['meanpressure']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_31.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('meanpressure')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_32['meantemp'].plot(kind='line', figsize=(8, 4), title='meantemp')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_33['humidity'].plot(kind='line', figsize=(8, 4), title='humidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_34['wind_speed'].plot(kind='line', figsize=(8, 4), title='wind_speed')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_35['meanpressure'].plot(kind='line', figsize=(8, 4), title='meanpressure')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_36['date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_36, x='meantemp', y='date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_37['date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_37, x='humidity', y='date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_38['date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_38, x='wind_speed', y='date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_39['date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_39, x='meanpressure', y='date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
train.describe().style.background_gradient(cmap="purples")
test.describe().style.background_gradient(cmap="Oranges")
# Out:
# <style type="text/css">
# #T_4f79e_row0_col0, #T_4f79e_row0_col1, #T_4f79e_row0_col2, #T_4f79e_row7_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_4f79e_row0_col3 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_4f79e_row1_col0 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_4f79e_row1_col1 {
#   background-color: #fda762;
#   color: #000000;
# }
# #T_4f79e_row1_col2, #T_4f79e_row5_col2 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_4f79e_row1_col3, #T_4f79e_row4_col3 {
#   background-color: #842904;
#   color: #f1f1f1;
# }
# #T_4f79e_row2_col0, #T_4f79e_row3_col1, #T_4f79e_row3_col2, #T_4f79e_row3_col3 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_4f79e_row2_col1 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_4f79e_row2_col2 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_4f79e_row2_col3 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_4f79e_row3_col0 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_4f79e_row4_col0 {
#   background-color: #feead6;
#   color: #000000;
# }
# #T_4f79e_row4_col1 {
#   background-color: #fdd4aa;
#   color: #000000;
# }
# #T_4f79e_row4_col2 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_4f79e_row5_col0 {
#   background-color: #fee6ce;
#   color: #000000;
# }
# #T_4f79e_row5_col1 {
#   background-color: #fda35c;
#   color: #000000;
# }
# #T_4f79e_row5_col3 {
#   background-color: #812804;
#   color: #f1f1f1;
# }
# #T_4f79e_row6_col0 {
#   background-color: #fdd9b5;
#   color: #000000;
# }
# #T_4f79e_row6_col1 {
#   background-color: #f77a27;
#   color: #f1f1f1;
# }
# #T_4f79e_row6_col2 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_4f79e_row6_col3 {
#   background-color: #802704;
#   color: #f1f1f1;
# }
# #T_4f79e_row7_col0 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_4f79e_row7_col1 {
#   background-color: #c03f02;
#   color: #f1f1f1;
# }
# #T_4f79e_row7_col2 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# </style>
# <table id="T_4f79e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f79e_level0_col0" class="col_heading level0 col0" >meantemp</th>
#       <th id="T_4f79e_level0_col1" class="col_heading level0 col1" >humidity</th>
#       <th id="T_4f79e_level0_col2" class="col_heading level0 col2" >wind_speed</th>
#       <th id="T_4f79e_level0_col3" class="col_heading level0 col3" >meanpressure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f79e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_4f79e_row0_col0" class="data row0 col0" >114.000000</td>
#       <td id="T_4f79e_row0_col1" class="data row0 col1" >114.000000</td>
#       <td id="T_4f79e_row0_col2" class="data row0 col2" >114.000000</td>
#       <td id="T_4f79e_row0_col3" class="data row0 col3" >114.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4f79e_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_4f79e_row1_col0" class="data row1 col0" >21.713079</td>
#       <td id="T_4f79e_row1_col1" class="data row1 col1" >56.258362</td>
#       <td id="T_4f79e_row1_col2" class="data row1 col2" >8.143924</td>
#       <td id="T_4f79e_row1_col3" class="data row1 col3" >1004.035090</td>
#     </tr>
#     <tr>
#       <th id="T_4f79e_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_4f79e_row2_col0" class="data row2 col0" >6.360072</td>
#       <td id="T_4f79e_row2_col1" class="data row2 col1" >19.068083</td>
#       <td id="T_4f79e_row2_col2" class="data row2 col2" >3.588049</td>
#       <td id="T_4f79e_row2_col3" class="data row2 col3" >89.474692</td>
#     </tr>
#     <tr>
#       <th id="T_4f79e_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_4f79e_row3_col0" class="data row3 col0" >11.000000</td>
#       <td id="T_4f79e_row3_col1" class="data row3 col1" >17.750000</td>
#       <td id="T_4f79e_row3_col2" class="data row3 col2" >1.387500</td>
#       <td id="T_4f79e_row3_col3" class="data row3 col3" >59.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4f79e_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_4f79e_row4_col0" class="data row4 col0" >16.437198</td>
#       <td id="T_4f79e_row4_col1" class="data row4 col1" >39.625000</td>
#       <td id="T_4f79e_row4_col2" class="data row4 col2" >5.563542</td>
#       <td id="T_4f79e_row4_col3" class="data row4 col3" >1007.437500</td>
#     </tr>
#     <tr>
#       <th id="T_4f79e_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_4f79e_row5_col0" class="data row5 col0" >19.875000</td>
#       <td id="T_4f79e_row5_col1" class="data row5 col1" >57.750000</td>
#       <td id="T_4f79e_row5_col2" class="data row5 col2" >8.069444</td>
#       <td id="T_4f79e_row5_col3" class="data row5 col3" >1012.739316</td>
#     </tr>
#     <tr>
#       <th id="T_4f79e_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_4f79e_row6_col0" class="data row6 col0" >27.705357</td>
#       <td id="T_4f79e_row6_col1" class="data row6 col1" >71.902778</td>
#       <td id="T_4f79e_row6_col2" class="data row6 col2" >10.068750</td>
#       <td id="T_4f79e_row6_col3" class="data row6 col3" >1016.739583</td>
#     </tr>
#     <tr>
#       <th id="T_4f79e_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_4f79e_row7_col0" class="data row7 col0" >34.500000</td>
#       <td id="T_4f79e_row7_col1" class="data row7 col1" >95.833333</td>
#       <td id="T_4f79e_row7_col2" class="data row7 col2" >19.314286</td>
#       <td id="T_4f79e_row7_col3" class="data row7 col3" >1022.809524</td>
#     </tr>
#   </tbody>
# </table>

# %%
test.info()
train.info()
train.shape
test.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          114 non-null    object
#  1   meantemp      114 non-null    float64
#  2   humidity      114 non-null    float64
#  3   wind_speed    114 non-null    float64
#  4   meanpressure  114 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB
# (114, 5)

# %%
df=pd.concat([train,test])
df.head()
# Out:
#          date  meantemp  humidity  wind_speed  meanpressure
# 0  2013-01-01 10.000000 84.500000    0.000000   1015.666667
# 1  2013-01-02  7.400000 92.000000    2.980000   1017.800000
# 2  2013-01-03  7.166667 87.000000    4.633333   1018.666667
# 3  2013-01-04  8.666667 71.333333    1.233333   1017.166667
# 4  2013-01-05  6.000000 86.833333    3.700000   1016.500000

# %%
df.describe().style.background_gradient(cmap="blues")
df.isnull().sum()
df.shape
# Out:
# (1576, 5)

# %%
df.shape
df.index=pd.to_datetime(df['date'])
df['year']=df.index.year
df['month']=df.index.month
df.sample()
# Out:
#                   date  meantemp  humidity  wind_speed  meanpressure  year  \
# date
# 2016-04-12  2016-04-12 30.200000 36.200000   19.380000   1006.333333  2016
#
#             month
# date
# 2016-04-12      4

# %%
import plotly.graph_objects as go

fig_temp = go.Figure()
fig_temp.add_trace(go.Scatter(
    x=df.index,
    y=df['meantemp'],
    mode='lines',
    line=dict(color='orange', width=2)
))

fig_temp.show()
fig_temp = go.Figure()
fig_temp.add_trace(go.Scatter(
    x=df.index,
    y=df['humidity'],
    mode='lines',
    line=dict(color='pink', width=2)
))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a71bb6f6-7dfa-41e4-9f82-b8dfde895cec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a71bb6f6-7dfa-41e4-9f82-b8dfde895cec")) {                    Plotly.newPlot(                        "a71bb6f6-7dfa-41e4-9f82-b8dfde895cec",                        [{"line":{"color":"orange","width":2},"mode":"lines","x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-01T00:00:00","2013-06-02T00:00:00","2013-06-03T0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1926738b-99c7-4418-93eb-a49922afe5c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1926738b-99c7-4418-93eb-a49922afe5c3")) {                    Plotly.newPlot(                        "1926738b-99c7-4418-93eb-a49922afe5c3",                        [{"line":{"color":"pink","width":2},"mode":"lines","x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-01T00:00:00","2013-06-02T00:00:00","2013-06-03T00: ...
